# %% [markdown]
# # Downloading coinmetrics Pricedata
# This script can't download the pricedata from the coinmetric website as this is prevented from coinmetric which wants you

# %%
import urllib.request
import os.path
if not os.path.isfile('./data/coinmetric_btc.csv'):
    print("./data/coinmetric_btc.csv is not existing!")
    print("Download from https://coinmetrics.io/community-network-data/#comm-files (Bitcoin)")
    print("rename and place it in the data-folder")

# %%
import pandas as pd
btc = pd.read_csv("./data/coinmetric_btc.csv",\
                  index_col="date",parse_dates=["date"])
btc
# Out:
# /home/kim/tmp/s2f-python/.env/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#             AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# date
# 2009-01-03          0       0            0              NaN         NaN
# 2009-01-04          0       0            0              NaN         NaN
# 2009-01-05          0       0            0              NaN         NaN
# 2009-01-06          0       0            0              NaN         NaN
# 2009-01-07          0       0            0              NaN         NaN
# ...               ...     ...          ...              ...         ...
# 2020-05-05     970464     158    190305322     1.204464e+06    1.599594
# 2020-05-06     972369     154    186296384     1.209717e+06    1.645748
# 2020-05-07    1020443     147    194007072     1.319776e+06    1.762466
# 2020-05-08     949216     137    174365143     1.272738e+06    1.735049
# 2020-05-09     906900     136    175387503     1.289614e+06    1.685279
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# date
# 2009-01-03            NaN  0.000000e+00           NaN         NaN         NaN
# 2009-01-04            NaN  0.000000e+00           NaN         NaN         NaN
# 2009-01-05            NaN  0.000000e+00           NaN         NaN         NaN
# 2009-01-06            NaN  0.000000e+00           NaN         NaN         NaN
# 2009-01-07            NaN  0.000000e+00           NaN         NaN         NaN
# ...                   ...           ...           ...         ...         ...
# 2020-05-05   1.650160e+11  1.031612e+11  1.608446e+13    0.000219    1.968212
# 2020-05-06   1.701928e+11  1.034137e+11  1.610481e+13    0.000205    1.902750
# 2020-05-07   1.835621e+11  1.041507e+11  1.610481e+13    0.000265    2.643640
# 2020-05-08   1.811098e+11  1.043831e+11  1.610481e+13    0.000320    3.158286
# 2020-05-09   1.759462e+11  1.044018e+11  1.610481e+13    0.000275    2.631075
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# date        ...
# 2009-01-03  ...             NaN              NaN              NaN
# 2009-01-04  ...             NaN              NaN              NaN
# 2009-01-05  ...             NaN              NaN              NaN
# 2009-01-06  ...             NaN              NaN              NaN
# 2009-01-07  ...             NaN              NaN              NaN
# ...         ...             ...              ...              ...
# 2020-05-05  ...    1.852142e+09         0.642400      5772.528246
# 2020-05-06  ...    2.429543e+09         0.766611      7104.043524
# 2020-05-07  ...    3.741749e+09         1.091965     10912.830187
# 2020-05-08  ...    3.160808e+09         0.874559      8622.557629
# 2020-05-09  ...    2.500358e+09         0.858406      8221.244046
#
#             TxTfrValMedNtv  TxTfrValMedUSD    TxTfrValNtv   TxTfrValUSD  \
# date
# 2009-01-03             NaN             NaN       0.000000           NaN
# 2009-01-04             NaN             NaN       0.000000           NaN
# 2009-01-05             NaN             NaN       0.000000           NaN
# 2009-01-06             NaN             NaN       0.000000           NaN
# 2009-01-07             NaN             NaN       0.000000           NaN
# ...                    ...             ...            ...           ...
# 2020-05-05        0.010709       96.232930  512106.435390  4.601727e+09
# 2020-05-06        0.010707       99.217358  633066.838734  5.866512e+09
# 2020-05-07        0.010841      108.338081  937529.607782  9.369439e+09
# 2020-05-08        0.010344      101.983562  711478.024909  7.014692e+09
# 2020-05-09        0.009786       93.724796  661163.090355  6.332183e+09
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# date
# 2009-01-03            NaN           NaN           NaN
# 2009-01-04            NaN           NaN           NaN
# 2009-01-05            NaN           NaN           NaN
# 2009-01-06            NaN           NaN           NaN
# 2009-01-07            NaN           NaN           NaN
# ...                   ...           ...           ...
# 2020-05-05       0.050217      0.035826      0.078059
# 2020-05-06       0.050148      0.034085      0.078077
# 2020-05-07       0.050460      0.035932      0.077684
# 2020-05-08       0.050436      0.036097      0.077616
# 2020-05-09       0.050405      0.036619      0.077731
#
# [4145 rows x 40 columns]

# %%
daily_prices = pd.DataFrame()
daily_prices['price'] = btc.PriceUSD.resample('M').mean()
btc = daily_prices
# the first year is not very reliable, we'll skip it.
#btc = btc[btc.index > '2012-1-1']
# Do we really need that?!
# vielleicht besser btc.notnull()
btc.fillna(method='ffill',inplace=True) # replace Null-values with forwardfill
print("So now we have {} datapoints".format(btc.shape[0]))
btc
# Out:
# So now we have 137 datapoints
#                   price
# date
# 2009-01-31          NaN
# 2009-02-28          NaN
# 2009-03-31          NaN
# 2009-04-30          NaN
# 2009-05-31          NaN
# ...                 ...
# 2020-01-31  8365.735932
# 2020-02-29  9646.192816
# 2020-03-31  6885.037265
# 2020-04-30  7224.347704
# 2020-05-31  9254.963920
#
# [137 rows x 1 columns]

# %%
btc.to_csv ('data/coinmetric_btc_monthly.csv', index = True, header=True)
